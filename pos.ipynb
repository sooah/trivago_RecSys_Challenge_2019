# %%
import os
import pandas as pd
import numpy as np

# %%
imp_pri = pd.read_csv('impression_price.csv')

# %%
pos_ref = pd.read_csv('positive_reference.csv')
pos_ref
# Out:
#         Unnamed: 0  reference
# 0               15    1257342
# 1              115    2795374
# 2              177    1320460
# 3              180    3143258
# 4              181    2552514
# 5              184     110591
# 6              191     138930
# 7              196     129881
# 8              230       8561
# 9              236    2529658
# 10             237     921237
# 11             240    9167996
# 12             260     104499
# 13             264    4138580
# 14             293    6893402
# 15             296    3191226
# 16             466    3404929
# 17             468    9164598
# 18             490       8602
# 19             495    2793224
# 20             542    9112068
# 21             550    1236209
# 22             564     327111
# 23             593    9590036
# 24             599    3753160
# 25             604    5170834
# 26             607     107674
# 27             608    6337814
# 28             627     434856
# 29             628      42349
# ...
